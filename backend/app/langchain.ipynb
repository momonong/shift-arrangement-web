# %%
import openai
from langchain.chains import OpenAIChain
import os
from dotenv import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/morris/jubo-web/backend/app/testing.ipynb 儲存格 1 line 1
# ----> <a href='vscode-notebook-cell:/home/morris/jubo-web/backend/app/testing.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import openai
#       <a href='vscode-notebook-cell:/home/morris/jubo-web/backend/app/testing.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> from langchain.chains import OpenAIChain
#       <a href='vscode-notebook-cell:/home/morris/jubo-web/backend/app/testing.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import os
#
# ModuleNotFoundError: No module named 'openai'

# %%
# 加載 .env 檔案
load_dotenv()

# 從環境變數中獲取 API 金鑰
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
# 初始化 Langchain
chain = OpenAIChain()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/morris/jubo-web/backend/app/testing.ipynb 儲存格 3 line 2
#       <a href='vscode-notebook-cell:/home/morris/jubo-web/backend/app/testing.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # 初始化 Langchain
# ----> <a href='vscode-notebook-cell:/home/morris/jubo-web/backend/app/testing.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> chain = OpenAIChain()
#
# NameError: name 'OpenAIChain' is not defined
