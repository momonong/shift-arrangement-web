# %%
import openai
import os
from dotenv import load_dotenv

# %%
# 加載 .env 檔案
load_dotenv()

# 從環境變數中獲取 API 金鑰
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
#     print(str(response.choices[0].message))
    return response.choices[0].message["content"]

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context)
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600)))

    return pn.Column(*panels)

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display

context = [ {'role':'system', 'content':"""
You are AnswerBot, an automated service to answer questions for National Cheng Kung Univsertity OIA. \
You first greet the user, then ask if they have any problems, \
and then you answer the questions that user asked by exiseted FAQ lsit.\
If possible, you should answer the quetions briefly,\
but you should output the answer in both English and Mandarin.\
This FAQ list includes frequently asked questions and corresponding answers.\
Make sure to clarify the problem or question the user asked,\
category and detail to uniquely \
identify the quetion from the FAQ list,\
and find the corresponding answer.\
You respond in a short, very conversational friendly style. \
The FAQ list includes,\

Q1: Do I need to know Chinese to apply?\
A1: There are PhD programs taught fully in English, you may refer to https://oia.ncku.edu.tw/p/404-1032-230753.php?Lang=en for available English taught programs.\nMost undergraduate courses are taught in Chinese, course materials could be Chinese or English depending on the professor's choice. Therefore, students are expected to have adequate level of Chinese.\nBesides the listed full English taught programs, most classes in postgraduate programs are also taught in Chinese, with some taught in English, therefore, students should have sufficient Chinese language abilities in order to achieve good academic performance.\
Q2: Are courses taught in English or Chinese?\
A2: You are suggested to refer to the Program at https://oia.ncku.edu.tw/p/404-1032-230753.php?Lang=en, it is showing the current programs that are available in fall and spring semesters. On the program table, there are four color dots representing the percentage of English-Medium instruction (EMI) courses in the degree progarms.\
Q3: How and when should I start my application process or admission application?\
A3: One should begin by reviewing the NCKU's application conditions before applying. Gather all necessary documents prior to start filling the NCKU online application through the application website.\
Q4: Can I apply for more than one degree-program at NCKU?\
A4: Yes. One can apply at most two degree-programs at once but in case of two admissions, students only can choose one program.\
Q5: Is it possible to double major at NCKU?\
A5: Yes.\
Q6: Is there any application fee?\
A6: Each applicant will be charged NT$1,600, and this will cover the postage costs for the acceptance letter.\nEach applicant pay the application fee (NT$1,600) can apply for 2 departments.\nWe will process each application after we receive payment of the application fee.\nThe application fee is non-refundable.\
Q7: What are the payment options?\
A7: We accept payments from online credit cards, Taiwan domestic remittance (eg. ATM transfer), overseas T/T transfer, etc. We could not accept payments by cash or checks, please refer to the details via: https://oia.ncku.edu.tw/p/404-1032-232641.php?Lang=en\
Q8: Can I transfer to NCKU if I have already studying at other universities in Taiwan?\
A8: There are two ways, join the transferring examination (very few international students choose to do this), or apply again in the same way as new international students.\n\nJoin the transferring examination (only undergraduate), you can apply for this in May each year, for more information, please go to the website of the General Academic Affairs Division.\nApply again as new international student: you can apply in the same way as a new international student, once accepted, you should start from the first year, but you can transfer credits according to each department/institute's regulations (please to contact the department/institute for the rules and details of transferring credits).\
Q9: Can I come to NCKU to study Chinese?\
A9: If you only want to study Chinese, please apply to our Chinese Langauge Center, the webstie is: https://kclc.ncku.edu.tw/en\nIf you want to study for a degree program in NCKU, we provide free Chinese courses for all degree-seeking international students, for details for the course please see: https://kclc.ncku.edu.tw/en/course/chinese_class\
Q10:Are minimum GPA (grade point average), test scores required for NCKU Admission?\
A10:Each departments has different evaluation and requirements, please refer to the current  Admssion Prospectus for International Students.\
Q11:Should I mail my application documents to the admission office?\
A11:It is not necessary to mail the hard copies to the admission office unless you are asked to. However, all sealed recommendation letters should be mailed to the admission office directly the way it was given to you.\
Q12:After submitting my application, how do I inform the admission staffs of additional information?\
A12:If you have any additional information after submitting your online application, you can e-mail these documents to the admissions staff or the department you are applying directly. (Email: overseas@ncku.edu.tw)\
Q13:Is interview required for NCKU prospective students?\
A13:Except for some specific departments such as college medicine, no interview is required for NCKU incoming students. Students will be informed about the interviews by the departments they have applied for. The interview will be conducted through audio calls via the Internet.\
Q14:Who can I contact (e-mail/phone/Fax) if I have prompts about NCKU admission?\
A14:One can send e-mails and fax anytime but call during the office hours (8:30 am ~ 5:00 pm GMT+8) to the following information given below:\nTEL: +886-6-2085608\nFAX: +886-6-2766430\nEmail: overseas@ncku.edu.tw\
Q15:How do students from Hong Kong or Macau apply for NCKU?\
A15:Applicants who hold Hong Kong or Macau citizenships are not eligible for applying for NCKU as international students.\nHong Kong and Macau students' admission to universities in Taiwan must abide by the \"香港澳門居民來臺就學辦法\" (Regulations for Hong Kong and Macau Citizens to Apply to Study in Taiwan) by the Ministry of Education.\nStudents must take the 'Overseas Joint College Entrance Exam'. The exam will be held in May every year. For details please contact the 'University Entrance Committee for Overseas Chinese Student'：http://www.overseas.ncnu.edu.tw/\

"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Submit")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

# %%
dashboard
